# %% [markdown]
# # Pandas-1

# %%
#importing pandas 
import pandas as pd

# %%
#Read csv file and store in variable data
data=pd.read_csv("addresses.csv")

# %%
#To display data
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
#Display top 5 data rows in dataset
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
#Display last 5 rows in dataset 
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
#Give count of record
data.count()
# Out:
# id                21
# location_id       21
# address_1         21
# address_2          2
# city              21
# state_province    21
# postal_code       21
# country           21
# dtype: int64

# %%
#Checking null value
data.isnull()
# Out:
#        id  location_id  address_1  address_2   city  state_province  \
# 0   False        False      False       True  False           False
# 1   False        False      False       True  False           False
# 2   False        False      False       True  False           False
# 3   False        False      False       True  False           False
# 4   False        False      False       True  False           False
# 5   False        False      False       True  False           False
# 6   False        False      False       True  False           False
# 7   False        False      False       True  False           False
# 8   False        False      False       True  False           False
# 9   False        False      False       True  False           False
# 10  False        False      False       True  False           False
# 11  False        False      False      False  False           False
# 12  False        False      False       True  False           False
# ...

# %%
#Gives statastical values
data.describe()
# Out:
#               id  location_id
# count  21.000000    21.000000
# mean   11.000000    11.095238
# std     6.204837     6.363213
# min     1.000000     1.000000
# 25%     6.000000     6.000000
# 50%    11.000000    11.000000
# 75%    16.000000    16.000000
# max    21.000000    22.000000

# %%
#Gievs type of dataset 
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Gives all columns names
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
#Display city column
data['city']
# Out:
# 0            Redwood City
# 1               San Mateo
# 2               San Mateo
# 3               San Mateo
# 4               San Mateo
# 5              Menlo Park
# 6              Menlo Park
# 7              Menlo Park
# 8            Redwood City
# 9            Redwood City
# 10           Redwood City
# 11           Redwood City
# 12           Redwood City
# 13           Redwood City
# 14          San Francisco
# 15              Sunnyvale
# 16    South San Francisco
# 17           Redwood City
# 18              San Mateo
# 19                Belmont
# 20          San Francisco
# Name: city, dtype: object

# %%
#Display city column with column name 
data[['city']]
# Out:
#                    city
# 0          Redwood City
# 1             San Mateo
# 2             San Mateo
# 3             San Mateo
# 4             San Mateo
# 5            Menlo Park
# 6            Menlo Park
# 7            Menlo Park
# 8          Redwood City
# 9          Redwood City
# 10         Redwood City
# 11         Redwood City
# 12         Redwood City
# 13         Redwood City
# 14        San Francisco
# 15            Sunnyvale
# 16  South San Francisco
# 17         Redwood City
# 18            San Mateo
# 19              Belmont
# 20        San Francisco

# %%
#Display type of given column
type(data[['city']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Displays multiple columns
data[['city','address_1']]
# Out:
#                    city                   address_1
# 0          Redwood City       2600 Middlefield Road
# 1             San Mateo            24 Second Avenue
# 2             San Mateo            24 Second Avenue
# 3             San Mateo            24 Second Avenue
# 4             San Mateo            24 Second Avenue
# 5            Menlo Park           800 Middle Avenue
# 6            Menlo Park              500 Arbor Road
# 7            Menlo Park           800 Middle Avenue
# 8          Redwood City       2510 Middlefield Road
# 9          Redwood City       1044 Middlefield Road
# 10         Redwood City         2140 Euclid Avenue.
# 11         Redwood City       1044 Middlefield Road
# 12         Redwood City         399 Marine Parkway.
# 13         Redwood City          660 Veterans Blvd.
# 14        San Francisco        1500 Valencia Street
# 15            Sunnyvale         1161 South Bernardo
# 16  South San Francisco     409 South Spruce Avenue
# ...

# %%
#To read excel,xls type of file
df=pd.read_excel('airline.xls')

# %%
#Display dataset
df
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
df.head()
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %%
df1=pd.read_excel('airline.xls')

# %%
df1
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
#Reading sheet 2 from airline1.xls
pd.read_excel("airline1.xls" , sheet_name = "Sheet2")
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
#Reading sheet3 from airline1 and giving column name to sheet
dt = pd.read_excel("airline1.xls" , sheet_name = "Sheet3" , header=None , names=['a', 'b' , 'c','d','e','f'])

# %%
dt
# Out:
#        a       b      c       d      e      f
# 0   1960   5.554  0.441  0.3193  3.089  1.481
# 1   1961   5.465  0.460  0.3079  3.122  1.736
# 2   1962   5.825  0.485  0.3783  3.184  1.926
# 3   1963   6.876  0.506  0.4180  3.263  2.041
# 4   1964   7.823  0.538  0.5163  3.412  1.997
# 5   1965   9.120  0.564  0.5879  3.623  2.257
# 6   1966  10.512  0.586  0.5369  4.074  2.742
# 7   1967  13.020  0.622  0.4443  4.710  3.564
# 8   1968  15.261  0.666  0.3052  5.217  4.767
# 9   1969  16.313  0.731  0.2332  5.569  6.511
# 10  1970  16.002  0.831  0.1883  5.495  7.627
# 11  1971  15.876  0.906  0.2023  5.334  8.673
# 12  1972  16.662  1.000  0.2506  5.345  8.331
# 13  1973  17.014  1.056  0.2668  5.662  8.557
# 14  1974  19.305  1.131  0.2664  5.729  9.508
# 15  1975  18.721  1.247  0.2301  5.722  9.062

# %%
dt.to_csv('test1.csv' , index= False )

# %%
dt.to_excel("test2.xlsx")

# %%
dt.head()
# Out:
#       a      b      c       d      e      f
# 0  1960  5.554  0.441  0.3193  3.089  1.481
# 1  1961  5.465  0.460  0.3079  3.122  1.736
# 2  1962  5.825  0.485  0.3783  3.184  1.926
# 3  1963  6.876  0.506  0.4180  3.263  2.041
# 4  1964  7.823  0.538  0.5163  3.412  1.997

# %%
dt.tail()
# Out:
#        a       b      c       d      e      f
# 11  1971  15.876  0.906  0.2023  5.334  8.673
# 12  1972  16.662  1.000  0.2506  5.345  8.331
# 13  1973  17.014  1.056  0.2668  5.662  8.557
# 14  1974  19.305  1.131  0.2664  5.729  9.508
# 15  1975  18.721  1.247  0.2301  5.722  9.062

# %%
type(dt)
# Out:
# pandas.core.frame.DataFrame

# %%
dt.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
list(dt.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
dt[['a','d']]
# Out:
#        a       d
# 0   1960  0.3193
# 1   1961  0.3079
# 2   1962  0.3783
# 3   1963  0.4180
# 4   1964  0.5163
# 5   1965  0.5879
# 6   1966  0.5369
# 7   1967  0.4443
# 8   1968  0.3052
# 9   1969  0.2332
# 10  1970  0.1883
# 11  1971  0.2023
# 12  1972  0.2506
# 13  1973  0.2668
# 14  1974  0.2664
# 15  1975  0.2301

# %%
d=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Rading html file
x=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
x
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 1

# %%
#Diplay in tabuler format
x[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...
