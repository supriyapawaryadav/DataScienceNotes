# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data[['Name','Sex','Ticket','Cabin','Embarked']].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#list of categorical columns
data.dtypes[data.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes=='object'].index] #diplay categorical data
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#List of numerical columns
data.dtypes[data.dtypes=='int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
#Total numbers of servived people
#data.head(3)
data[data['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Servived male persons from the set
data[(data['Survived']==1) & (data['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
#Survived male total count
len(data[(data['Survived']==1) & (data['Sex']=='male')])
# Out:
# 109

# %%
#Total number of female survived
len(data[(data['Survived']==1) & (data['Sex']=='female')])
#len(data[(data['Survived'] == 0) & (data['Sex'] == 'male')])
# Out:
# 233

# %%
data.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#maximum Faredata
max(data['Fare'])
# Out:
# 512.3292

# %%
#Name of maximum Fare paid 
data[data['Fare'] ==max(data['Fare'])] [['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
#Name of the person who paid minimum fare
data[data['Fare']==min(data['Fare'])][['Name']]
# Out:
#                                  Name
# 179               Leonard, Mr. Lionel
# 263             Harrison, Mr. William
# 271      Tornquist, Mr. William Henry
# 277       Parkes, Mr. Francis "Frank"
# 302   Johnson, Mr. William Cahoone Jr
# 413    Cunningham, Mr. Alfred Fleming
# 466             Campbell, Mr. William
# 481  Frost, Mr. Anthony Wood "Archie"
# 597               Johnson, Mr. Alfred
# 633     Parr, Mr. William Henry Marsh
# 674        Watson, Mr. Ennis Hastings
# 732              Knight, Mr. Robert J
# 806            Andrews, Mr. Thomas Jr
# 815                  Fry, Mr. Richard
# 822   Reuchlin, Jonkheer. John George

# %%
#The exact null value count from each column
#len(data[data['Cabin'].isnull()==True])
data['Cabin'].isna().sum()
# Out:
# 687

# %%
#Count total NaN values from entire dataset
data.isna().sum().sum()
# Out:
# 866

# %%
#count NaN values from a single dataframe row
data.loc[[1]].isna().sum().sum()
# Out:
# 0

# %%
#Create new column in dataset
data['New_col']='City'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 0      0         A/5 21171   7.2500   NaN        S    City
# 1      0          PC 17599  71.2833   C85        C    City
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City
# 3      0            113803  53.1000  C123        S    City
# ...

# %%
#Create new col which is sum of two existing col
data['Sum']= data['Age']+data['PassengerId']

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked New_col   Sum
# 0      0  A/5 21171   7.2500   NaN        S    City  23.0
# 1      0   PC 17599  71.2833   C85        C    City  40.0

# %%
#Delete any col temporary
data.drop('Sum',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to check col was deleted or not 
data.head(2) 
#col was not deleted permantly
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked New_col   Sum
# 0      0  A/5 21171   7.2500   NaN        S    City  23.0
# 1      0   PC 17599  71.2833   C85        C    City  40.0

# %%
#Deleting any one col permently 
data.drop('Sum',axis=1,inplace=True) # for this we add inplace= True

# %%
#Second option for Deleting any one col permently 
data=data.drop(0) #reassignment i.e store in data [droping 0th row record]
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 1      0          PC 17599  71.2833   C85        C    City
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 1      0          PC 17599  71.2833   C85        C    City
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City

# %%
#delete any row
data.drop(axis=0,index=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
#Know the details of any row number by iloc 
#iloc and loc both access record on row level
#iloc =internal indexing{default start with 0}
#loc = named indexing
data.iloc[0] # getting the details of 1st row in dataset
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# New_col                                                     City
# Name: 1, dtype: object

# %%
#Know the details of any row number by loc
data.loc[3] # gives the details of 3rd row in dataset
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# New_col                                                City
# Name: 3, dtype: object

# %%
#know the details of 5 to 7 row and every col
data.iloc[5:8]
# Out:
#    PassengerId  Survived  Pclass  \
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked New_col
# 6      0   17463  51.8625   E46        S    City
# 7      1  349909  21.0750   NaN        S    City
# 8      2  347742  11.1333   NaN        S    City

# %%
#know the details of 5 to 7 row and any 2 specific col
data.iloc[5:8:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 6            7         0       1
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked New_col
# 6      0   17463  51.8625   E46        S    City
# 8      2  347742  11.1333   NaN        S    City

# %%
#know details of every row and specific col by slicing 
data.loc[:,['Pclass','Age']]
# Out:
#      Pclass   Age
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# 5         3   NaN
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [890 rows x 2 columns]

# %%
#know the details of rows for specific rows and sequence of col
data.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 1      0          PC 17599  71.2833   C85        C    City
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City
# 3      0            113803  53.1000  C123        S    City
# 4      0            373450   8.0500   NaN        S    City

# %%
#know the details of rows for specific rows and sequence of col
# show the record from 103 to 108 from Survived and passenger col
data.loc[103:108,['Survived','Pclass']] #getting subset of dataset
# Out:
#      Survived  Pclass
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3
# 107         1       3
# 108         0       3

# %%
#only wrok with loc not with iloc coz here we using named indexes(fare ,cabin etc)
data.loc[3:4,['Fare','Cabin','Embarked']] #intersection of col
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
#for iloc we need to give internal index number of col
data.iloc[2:4,[9,10,11]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
#filter out all the col of passengerid and Pclass using iloc and loc
data.loc[: ,['PassengerId','Pclass']] # need to give named indexes of col
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.iloc[:,[0,2]] #in iloc need to give index number of col
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.iloc[[3,5],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 4            5         0       3
# 6            7         0       1

# %%
#Give all the record where age >35
data[data['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#age>35 and Pclass=1
data[(data['Age']>35) & (data['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#create subset of record 
data1=data.iloc[1:5,[2,3,4,5,9,10]]

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#Rename the abow indexes 2,3,4,5 as Name col 
#Reset indexes or set indexes
data1.set_index('Name')
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
#drop all records where we have null value in row
#dropna checkes axis wise(defalut axis=0 i.e row) Null value and delete those record
data1.dropna()
# Out:
#    Pclass                                          Name     Sex   Age  Fare  \
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1
#
#   Cabin
# 3  C123

# %%
# check null value col wise and drop that record
#difference: drop {drops given row and col} and dropna{before drop checks null value then it drop} 
data1.dropna(axis=1)
# Out:
#    Pclass                                          Name     Sex     Fare
# 2       3                        Heikkinen, Miss. Laina  female   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4       3                      Allen, Mr. William Henry    male   8.0500
# 5       3                              Moran, Mr. James    male   8.4583

# %%
#thresh :require that many non-NA(non null value) values.autherwise it will perform drop operation.
data1.dropna(axis=1,thresh=1)
#keeps dataset as it is coz thresh=1 i.e checks 1-non null col wise.It is present so it will not drop.
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
data1.dropna(axis=1,thresh=2) # checks 2 non null value in col ,if it is not present then it drop.
# Out:
#    Pclass                                          Name     Sex   Age     Fare
# 2       3                        Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4       3                      Allen, Mr. William Henry    male  35.0   8.0500
# 5       3                              Moran, Mr. James    male   NaN   8.4583

# %%
data1.dropna(axis=1,thresh=4) # 4 non NA value require ,if it is not present then drop that col.
#this all changes not permanent untill we set inplace=True
# Out:
#    Pclass                                          Name     Sex     Fare
# 2       3                        Heikkinen, Miss. Laina  female   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4       3                      Allen, Mr. William Henry    male   8.0500
# 5       3                              Moran, Mr. James    male   8.4583

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#Replace NaN with other value
data1.fillna('abc')
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   abc
#
#       Fare Cabin
# 2   7.9250   abc
# 3  53.1000  C123
# 4   8.0500   abc
# 5   8.4583   abc

# %%
#Replace NaN value with avg of Age
data1.fillna(data1['Age'].mean())
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male  32.0
#
#       Fare Cabin
# 2   7.9250  32.0
# 3  53.1000  C123
# 4   8.0500  32.0
# 5   8.4583  32.0

# %%
#group how many female and male data we have
data1.groupby('Sex').count()
# Out:
#         Pclass  Name  Age  Fare  Cabin
# Sex
# female       2     2    2     2      1
# male         2     2    1     2      0

# %%
#what is average age of female group & male group seprtly
data1.groupby('Sex').mean()['Age']
# Out:
# Sex
# female    30.5
# male      35.0
# Name: Age, dtype: float64

# %%
#Total fare paied by female and how many fare paied by male (i.e revenue)
data1.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    61.0250
# male      16.5083
# Name: Fare, dtype: float64

# %%
#Create subset of dataset
data2=data.iloc[0:4,0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
#merge operation
pd.concat([data1,data2]) #horizhontal merge opration (default axis=0)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   NaN
# 2       3                             Heikkinen, Miss. Laina  female   NaN
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male   NaN
#
#       Fare Cabin  PassengerId  Survived
# 2   7.9250   NaN          NaN       NaN
# 3  53.1000  C123          NaN       NaN
# 4   8.0500   NaN          NaN       NaN
# 5   8.4583   NaN          NaN       NaN
# 1      NaN   NaN          2.0       1.0
# 2      NaN   NaN          3.0       1.0
# ...

# %%
pd.concat([data1,data2],axis=1) # vertical merge operation
# Out:
#    Pclass                                          Name     Sex   Age  \
# 1     NaN                                           NaN     NaN   NaN
# 2     3.0                        Heikkinen, Miss. Laina  female  26.0
# 3     1.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4     3.0                      Allen, Mr. William Henry    male  35.0
# 5     3.0                              Moran, Mr. James    male   NaN
#
#       Fare Cabin  PassengerId  Survived  Pclass  \
# 1      NaN   NaN          2.0       1.0     1.0
# 2   7.9250   NaN          3.0       1.0     3.0
# 3  53.1000  C123          4.0       1.0     1.0
# 4   8.0500   NaN          5.0       0.0     3.0
# 5   8.4583   NaN          NaN       NaN     NaN
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# ...

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#divide Pclass with 3
data1['divide']=data['Pclass'].apply(lambda x : x/3)

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin    divide
# 2   7.9250   NaN  1.000000
# 3  53.1000  C123  0.333333
# 4   8.0500   NaN  1.000000
# 5   8.4583   NaN  1.000000

# %%
#using external function
def fun1(x):
    return x/3

# %%
data1['divide']=data['Pclass'].apply(fun1)

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin    divide
# 2   7.9250   NaN  1.000000
# 3  53.1000  C123  0.333333
# 4   8.0500   NaN  1.000000
# 5   8.4583   NaN  1.000000

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
#create new col ,store length of name in it
data2['len_name']=data2['Name'].apply(len)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  len_name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        51
# 2                             Heikkinen, Miss. Laina  female        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        44
# 4                           Allen, Mr. William Henry    male        24

# %%
#where PassengerId less then 3,  keep data as it is.
#where PassengerId > = 3 , replace it with logarithm
import math
def cust(x):
    if x<3:
        return x
    else:
        return math.log10(x)

# %%
data2['PassengerId_filter']=data2['PassengerId'].apply(cust)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  len_name  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        51
# 2                             Heikkinen, Miss. Laina  female        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        44
# 4                           Allen, Mr. William Henry    male        24
#
#    PassengerId_filter
# 1            2.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %%
#Replace female with 1 and male with 0
def fun(x):
    if x== 'female':
        return 1
    else:
        return 0

# %%
data2['Sex']=data2['Sex'].apply(fun)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  len_name  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1        51
# 2                             Heikkinen, Miss. Laina    1        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1        44
# 4                           Allen, Mr. William Henry    0        24
#
#    PassengerId_filter
# 1            2.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %%
#Take orignal data 
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col
# 1      0          PC 17599  71.2833   C85        C    City
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City
# 3      0            113803  53.1000  C123        S    City
# 4      0            373450   8.0500   NaN        S    City
# ...

# %%
#seprate data into 3 categories on amount they paid
#0-100 =A
#101-199=B
#200+=C

def test(x):
    if x <100:
        return "A"
    elif x > 100 and x <200:
        return "B"
    else :
        return "C"

# %%
data['Fare_categories']=data['Fare'].apply(test)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked New_col Fare_categories
# 1      0          PC 17599  71.2833   C85        C    City               A
# 2      0  STON/O2. 3101282   7.9250   NaN        S    City               A
# 3      0            113803  53.1000  C123        S    City               A
# ...
